# %% [markdown]
# # Music Recommendation System.

# %% [markdown]
# - Building a Music Recommendation System using Spotify API and Python.
# - To build a Music Recommendation System we need to have Access Token.
# - The access token serves as a temporary authorization credential, allowing the code to make authenticated requests to the Spotify API
# - Below Code helps to get it.

# %%
import requests
import base64

# paste here with  Client ID and Client Secret

CLIENT_ID = '21c3e79cf3c04054bdad09b5690bc7bf'
CLIENT_SECRET = '4dbb3bb55d704ae1b8e3e21f9c318952'

# Base64 encode the client ID and client secret

client_credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
client_credentials_base64 = base64.b64encode(client_credentials.encode())

# Request the access token

token_url = 'https://accounts.spotify.com/api/token'
headers = {
    'Authorization': f'Basic {client_credentials_base64.decode()}'
}
data = {
    'grant_type': 'client_credentials'
}
response = requests.post(token_url, data=data, headers=headers)

if response.status_code == 200:
    access_token = response.json()['access_token']
    print("Access token obtained successfully.")
else:
    print("Error obtaining access token.")
    exit()
# Out:
# Access token obtained successfully.

# %% [markdown]
# - A function to get music data from any playlist on Spotify.we need to install the Spotipy library, which is a Python library providing access to Spotify’s web API.

# %%
pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.0.0-py3-none-any.whl (250 kB)
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#                                               0.0/250.1 kB ? eta -:--:--
#      ---------                                61.4/250.1 kB ? eta -:--:--
#      ---------                                61.4/250.1 kB ? eta -:--:--
#      ---------                                61.4/250.1 kB ? eta -:--:--
#      ---------                                61.4/250.1 kB ? eta -:--:--
#      ------------                          81.9/250.1 kB 459.5 kB/s eta 0:00:01
#      ------------                          81.9/250.1 kB 459.5 kB/s eta 0:00:01
#      -------------                         92.2/250.1 kB 309.1 kB/s eta 0:00:01
#      -------------                         92.2/250.1 kB 309.1 kB/s eta 0:00:01
#      -------------                         92.2/250.1 kB 309.1 kB/s eta 0:00:01
#      ----------------                     112.6/250.1 kB 262.6 kB/s eta 0:00:01
#      ----------------                     112.6/250.1 kB 262.6 kB/s eta 0:00:01
#      -----------------                    122.9/250.1 kB 232.7 kB/s eta 0:00:01
#      -----------------                    122.9/250.1 kB 232.7 kB/s eta 0:00:01
#      -----------------                    122.9/250.1 kB 232.7 kB/s eta 0:00:01
#      --------------------                 143.4/250.1 kB 224.5 kB/s eta 0:00:01
#      -----------------------              163.8/250.1 kB 245.8 kB/s eta 0:00:01
#      -----------------------              163.8/250.1 kB 245.8 kB/s eta 0:00:01
#      -------------------------            174.1/250.1 kB 218.5 kB/s eta 0:00:01
#      -------------------------            174.1/250.1 kB 218.5 kB/s eta 0:00:01
#      ----------------------------         194.6/250.1 kB 222.6 kB/s eta 0:00:01
#      ----------------------------         194.6/250.1 kB 222.6 kB/s eta 0:00:01
#      -----------------------------        204.8/250.1 kB 214.7 kB/s eta 0:00:01
#      --------------------------------     225.3/250.1 kB 218.5 kB/s eta 0:00:01
#      --------------------------------     225.3/250.1 kB 218.5 kB/s eta 0:00:01
#      -----------------------------------  245.8/250.1 kB 221.8 kB/s eta 0:00:01
#      ------------------------------------ 250.1/250.1 kB 219.4 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in c:\users\poorn\anaconda3\lib\site-packages (from spotipy) (2.29.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\poorn\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\poorn\anaconda3\lib\site-packages (from spotipy) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\poorn\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\poorn\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\poorn\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2023.5.7)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.0.0 spotipy-2.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth

def get_trending_playlist_data(playlist_id, access_token):
    # Set up Spotipy with the access token
    sp = spotipy.Spotify(auth=access_token)

    # Get the tracks from the playlist
    playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id, name, artists, album(id, name)))')

    # Extract relevant information and store in a list of dictionaries
    music_data = []
    for track_info in playlist_tracks['items']:
        track = track_info['track']
        track_name = track['name']
        artists = ', '.join([artist['name'] for artist in track['artists']])
        album_name = track['album']['name']
        album_id = track['album']['id']
        track_id = track['id']

        # Get audio features for the track
        audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None

        # Get release date of the album
        try:
            album_info = sp.album(album_id) if album_id != 'Not available' else None
            release_date = album_info['release_date'] if album_info else None
        except:
            release_date = None

        # Get popularity of the track
        try:
            track_info = sp.track(track_id) if track_id != 'Not available' else None
            popularity = track_info['popularity'] if track_info else None
        except:
            popularity = None

        # Add additional track information to the track data
        track_data = {
            'Track Name': track_name,
            'Artists': artists,
            'Album Name': album_name,
            'Album ID': album_id,
            'Track ID': track_id,
            'Popularity': popularity,
            'Release Date': release_date,
            'Duration (ms)': audio_features['duration_ms'] if audio_features else None,
            'Explicit': track_info.get('explicit', None),
            'External URLs': track_info.get('external_urls', {}).get('spotify', None),
            'Danceability': audio_features['danceability'] if audio_features else None,
            'Energy': audio_features['energy'] if audio_features else None,
            'Key': audio_features['key'] if audio_features else None,
            'Loudness': audio_features['loudness'] if audio_features else None,
            'Mode': audio_features['mode'] if audio_features else None,
            'Speechiness': audio_features['speechiness'] if audio_features else None,
            'Acousticness': audio_features['acousticness'] if audio_features else None,
            'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
            'Liveness': audio_features['liveness'] if audio_features else None,
            'Valence': audio_features['valence'] if audio_features else None,
            'Tempo': audio_features['tempo'] if audio_features else None,
            # Add more attributes as needed
        }

        music_data.append(track_data)

    # Create a pandas DataFrame from the list of dictionaries
    df = pd.DataFrame(music_data)

    return df

# %% [markdown]
# The extracted information for all tracks is stored in the music_data list. The function then creates a DataFrame from the music_data list. The DataFrame organizes the music data in a tabular format, making it easier to analyze and work with the collected information.

# %%
playlist_id = '37i9dQZF1DZ06evO3bRZEQ'

# Call the function to get the music data from the playlist and store it in a DataFrame
music_df = get_trending_playlist_data(playlist_id, access_token)

# Display the DataFrame
print(music_df)
# Out:
#                                Track Name  \
# 0                          Top Lesi Poddi
# 1                               Darlingey
# 2                             Jorse Jorse
# 3                                Bad Boyz
# 4                             Telugammayi
# 5                                 Deo Deo
# 6                       Door Number Okati
# 7                     Neekemo Andamekkuva
# 8                             Jai Balayya
# 9                             Pakka Local
# 10                             Kanti Papa
# 11       Coka 2.0 (From "Liger (Telugu)")
# 12                      Box Badhalai Poyi
# 13                    Ittage Recchipodham
# 14                               Melikalu
# 15                               Gundello
# 16                Life Ante Itta Vundaala
# 17                           Saana Kastam
# 18                           Naughty Girl
# 19                        Dillaku Dillaku
# 20                            Raaye Raaye
# 21                               Baadshah
# 22             Neetho Ee Gadichina Kaalam
# 23                      Coka 2.0 (Telugu)
# 24                               Naakosam
# 25                                   Wkkb
# 26                             Yaevaindho
# 27                    Laali Paaduthunnadi
# 28                         Dhimmathirigae
# 29                            Door Number
# 30                             Jeva Nadhi
# 31                                 Roolar
# 32                            Tingo Tingo
# 33                                 Jorsey
# 34                           Singam Dance
# 35                              Mahammari
# 36                    Mabbe Masakesindile
# 37                      Monalisa Monalisa
# 38                        Relaare Relaare
# 39                          Hypare Hypare
# 40                          Mahanubhavudu
# 41        Coka 2.0 (From "Liger (Tamil)")
# 42                        Thakita Thakita
# 43                                Magallu
# 44                            Jeeva Nadhi
# 45                          Theme Of Hero
# 46                          Chitti Chitti
# 47                           Abbo Vadento
# 48                             Dilli Wala
# 49  Manjula Manjula (From "Vey Dharuvey")
#
#                                               Artists  \
# 0                               Sagar, Geetha Madhuri
# 1                     Devi Sri Prasad, Geetha Madhuri
# 2                        Daler Mehndi, Geetha Madhuri
# 3                        Priya Hemesh, Geetha Madhuri
# 4                     M. M. Keeravani, Geetha Madhuri
# 5         Geetha Madhuri, Raghu Ram, Bheems Ceciroleo
# 6                                      Geetha Madhuri
# 7   Devi Sri Prasad, Mika Singh, Geetha Madhuri, V...
# 8   Geetha Madhuri, Sahithi Chaganti, Satya Yamini...
# 9                               Geetha Madhuri, Sagar
# 10  Thaman S, Armaan Malik, Deepu, Geetha Madhuri,...
# 11  Jaani, Lijo George-Dj Chetas, Ram Miriyala, Ge...
# 12                              Sagar, Geetha Madhuri
# 13       Geetha Madhuri, Dhanunjay, Anudeep Dev, Arun
# 14                           Narendra, Geetha Madhuri
# 15                 Hemachandra Vedala, Geetha Madhuri
# 16   Devi Sri Prasad, Rahul Sipligunj, Geetha Madhuri
# 17                      L. V. Revanth, Geetha Madhuri
# 18                              Simha, Geetha Madhuri
# 19                              Tippu, Geetha Madhuri
# 20                       Raghu Kunche, Geetha Madhuri
# 21  Hemachandra Vedala, Shefali Alvares, Geetha Ma...
# 22                      Kalyani Malik, Geetha Madhuri
# 23  Jaani, Lijo George-Dj Chetas, Ram Miriyala, Ge...
# 24                              Deepu, Geetha Madhuri
# 25                     Geetha Madhuri, Aditya Iyengar
# 26             S. P. Balasubrahmanyam, Geetha Madhuri
# 27  S. P. Balasubrahmanyam, Geetha Madhuri, Balaji...
# 4   https://open.spotify.com/track/25LwhY6kKm6O2aL...  ...  0.7550    0
# 5   https://open.spotify.com/track/62z42XPbrv4mU3f...  ...  0.9640    5
# 6   https://open.spotify.com/track/5oyZumEp7fAIVnQ...  ...  0.8400   11
# 7   https://open.spotify.com/track/4qPwLohB0tei9j5...  ...  0.7200   10
# 8   https://open.spotify.com/track/798gW1ukNF0nQir...  ...  0.9100    2
# 9   https://open.spotify.com/track/3oLSlzMt3SD5PYS...  ...  0.9550    1
# 10  https://open.spotify.com/track/4WSam3pcMqExTIV...  ...  0.7870    9
# 11  https://open.spotify.com/track/5QKiLD7zEXvQc8V...  ...  0.9290    7
# 12  https://open.spotify.com/track/2tXmqzOJHKDsIWJ...  ...  0.9460    7
# 13  https://open.spotify.com/track/6InORfDvGGMxwR6...  ...  0.8140   11
# 14  https://open.spotify.com/track/5lDIz1ggqOGn6QL...  ...  0.8300    2
# 15  https://open.spotify.com/track/4QdALUGycjCaXbn...  ...  0.8010    9
# 16  https://open.spotify.com/track/0lFYzkfUlmusfjk...  ...  0.7050    7
# 17  https://open.spotify.com/track/6GbObXudr6oFWk8...  ...  0.6700    8
# 18  https://open.spotify.com/track/3EuSnLTNvP8MGA7...  ...  0.9200    0
# 19  https://open.spotify.com/track/7D4yGSGgtlMECMb...  ...  0.8330    4
# 20  https://open.spotify.com/track/5ZoUzf8G4HCyHwj...  ...  0.9140   10
# 21  https://open.spotify.com/track/7MtYzwt64CJppQV...  ...  0.9740    8
# 22  https://open.spotify.com/track/220ENw46j8SPA7z...  ...  0.3690    4
# 23  https://open.spotify.com/track/4DgUGhjUJFLEUT1...  ...  0.9290    7
# 24  https://open.spotify.com/track/5N8U8nH3qqK3kcx...  ...  0.6910    5
# 25  https://open.spotify.com/track/3lxRk0RZ4YeNijE...  ...  0.7800    2
# 26  https://open.spotify.com/track/3lFkByCu3i7cKoR...  ...  0.7340   11
# 27  https://open.spotify.com/track/5UqiJCMFtWbFNBf...  ...  0.3600   11
# 28  https://open.spotify.com/track/0Jid8Dg6yoDuLx4...  ...  0.9130    1
# 29  https://open.spotify.com/track/5nHphib1XzHTSrU...  ...  0.9110   11
# 30  https://open.spotify.com/track/1TVMTxaYtTuCgvP...  ...  0.0999    2
# 31  https://open.spotify.com/track/6sHu4R2GxklH7li...  ...  0.7820   10
# 32  https://open.spotify.com/track/7hl5up4hZ9S2si8...  ...  0.8920    0
# 33  https://open.spotify.com/track/05pZUcle4cJoJuN...  ...  0.7470    2
# 34  https://open.spotify.com/track/0n7yzdr3JqpxLZm...  ...  0.8960    9
# 35  https://open.spotify.com/track/1ov2PgxunEIe0Zo...  ...  0.8460    0
# 36  https://open.spotify.com/track/7uOgDYXZi0X8ss1...  ...  0.8840   10
# 37  https://open.spotify.com/track/16Ee6zrq4YFePPg...  ...  0.9060   11
# 38  https://open.spotify.com/track/7zeMJn8kFBGd5P0...  ...  0.8170    2
# 39  https://open.spotify.com/track/31AoWMao7HGObKC...  ...  0.9100    1
# 40  https://open.spotify.com/track/3jBAa2uo9aat7ke...  ...  0.6280    5
# 41  https://open.spotify.com/track/4lituJ6esaW8CHN...  ...  0.9260    7
# 42  https://open.spotify.com/track/1jU7ESBqLFd03RC...  ...  0.9560    1
# 43  https://open.spotify.com/track/10uHpzPnqT5091T...  ...  0.6470    9
# 44  https://open.spotify.com/track/5HmfZiIFxtOO1Zp...  ...  0.0778    9
# 45  https://open.spotify.com/track/4UT0KCiDh4gVIy9...  ...  0.5560    4
# 46  https://open.spotify.com/track/5oamh8hMy2BMtpD...  ...  0.7860    7
# 47  https://open.spotify.com/track/6VUKpwopUpJXcg9...  ...  0.5400    9
# 48  https://open.spotify.com/track/6CK8Mq2Rf3Sfh1o...  ...  0.9090    5
# 49  https://open.spotify.com/track/1ZHAgd7uGoui8l4...  ...  0.9570   10
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0     -3.423     0       0.1850        0.1040          0.000116    0.1190
# 1     -3.528     1       0.1450        0.1780          0.000121    0.2290
# 2     -7.426     1       0.3540        0.3480          0.000655    0.0425
# 3    -10.059     0       0.0733        0.4540          0.204000    0.1100
# 4    -11.498     1       0.0466        0.3690          0.000074    0.2920
# 5     -4.643     0       0.1600        0.1330          0.000034    0.3460
# 6     -6.698     0       0.3100        0.3210          0.002720    0.2380
# 7     -8.136     0       0.1640        0.2360          0.009740    0.0516
# 8     -6.103     0       0.1210        0.5970          0.000006    0.1970
# 9     -3.241     1       0.2190        0.2930          0.010700    0.1270
# 10    -7.617     0       0.0322        0.7980          0.104000    0.4070
# 11    -2.036     1       0.1180        0.6080          0.000005    0.1570
# 12    -2.295     1       0.1790        0.2260          0.008110    0.6390
# 13    -6.959     0       0.1990        0.1200          0.000002    0.0811
# 14    -3.442     1       0.1670        0.0300          0.000013    0.0795
# 15    -4.207     0       0.0668        0.2120          0.012300    0.0933
# 16    -6.812     1       0.1010        0.0910          0.000687    0.0793
# 17    -9.583     1       0.1730        0.1580          0.004450    0.5980
# 18    -7.415     0       0.0852        0.5510          0.270000    0.1130
# 19    -7.393     0       0.1320        0.1720          0.000000    0.2850
# 20    -8.108     0       0.2060        0.5790          0.001290    0.0828
# 21    -7.392     1       0.0729        0.2970          0.017200    0.0770
# 22   -11.706     1       0.0504        0.5280          0.001060    0.2720
# 23    -2.036     1       0.1180        0.6080          0.000005    0.1570
# 24    -7.289     0       0.0511        0.3160          0.000454    0.3280
# 25   -10.042     1       0.0584        0.5270          0.674000    0.0922
# 26   -10.215     0       0.0740        0.8140          0.001480    0.1820
# 27    -9.285     0       0.0479        0.8730          0.000053    0.2370
# 28    -5.076     0       0.0949        0.3690          0.003160    0.0655
# 29    -4.130     0       0.2060        0.2100          0.041600    0.0621
# 30   -12.849     0       0.0416        0.9760          0.000002    0.1030
# 31    -6.494     0       0.2070        0.3410          0.004250    0.0549
# 32    -7.141     1       0.1730        0.3180          0.007830    0.0958
# 33    -9.767     1       0.4410        0.8610          0.214000    0.0687
# 34    -4.739     0       0.0613        0.0328          0.000428    0.0563
# 35    -6.801     1       0.0835        0.2140          0.006670    0.1640
# 36    -7.627     0       0.4180        0.3740          0.000031    0.2520
# 37    -8.088     0       0.1950        0.4440          0.000000    0.2070
# 38    -4.974     0       0.3290        0.3180          0.000095    0.0632
# 39    -3.626     1       0.2560        0.0370          0.000033    0.0546
# 40    -7.442     1       0.0766        0.6040          0.032400    0.1160
# 41    -2.685     1       0.1060        0.5080          0.000010    0.1060
# 42    -6.328     1       0.0950        0.2120          0.822000    0.2320
# 43    -6.915     0       0.1260        0.1030          0.000001    0.2000
# 44   -11.891     0       0.0357        0.9760          0.000000    0.1150
# 45    -8.621     1       0.0741        0.3950          0.114000    0.1220
# 46    -8.000     0       0.1080        0.3710          0.067500    0.1030
# 47   -10.853     0       0.1290        0.4560          0.000010    0.0611
# 48    -4.912     0       0.0706        0.4610          0.000000    0.1560
# 49    -2.685     1       0.3300        0.5590          0.000203    0.1520
#
#     Valence    Tempo
# 0     0.898   82.874
# 1     0.904  141.938
# 2     0.748  173.950
# 3     0.438  125.999
# 4     0.713  136.040
# 5     0.629  133.045
# 6     0.610   81.003
# 7     0.917  109.986
# 8     0.837  127.997
# 9     0.810   93.000
# 10    0.786  101.060
# 11    0.828   96.969
# 12    0.810   96.038
# 13    0.553  102.991
# 14    0.820  159.871
# 15    0.793  123.943
# 16    0.607  150.020
# 17    0.564  137.908
# 18    0.936  129.059
# 19    0.790  110.992
# 20    0.909  129.008
# 21    0.388  114.003
# 22    0.617  113.052
# 23    0.828   96.969
# 24    0.920  116.021
# 25    0.130  129.970
# 26    0.577   86.474
# 27    0.701  142.495
# 28    0.872  104.997
# 29    0.754   81.832
# 30    0.213  108.048
# 31    0.829  110.978
# 32    0.791   96.993
# 33    0.846  174.042
# 34    0.694  115.969
# 35    0.791  129.961
# 36    0.619   75.016
# 37    0.555  139.908
# 38    0.664  112.653
# 39    0.725  149.787
# 40    0.707  191.986
# 41    0.820   97.004
# 42    0.555  147.009
# 43    0.720  114.945
# 44    0.480  135.090
# 45    0.490  202.259
# 46    0.722  123.021
# 47    0.562  112.013
# 48    0.844  159.935
# 49    0.829   92.195
#
# [50 rows x 21 columns]

# %% [markdown]
# Now let’s check if the data has any null values or not

# %%
print(music_df.isnull().sum())
# Out:
# Track Name          0
# Artists             0
# Album Name          0
# Album ID            0
# Track ID            0
# Popularity          0
# Release Date        0
# Duration (ms)       0
# Explicit            0
# External URLs       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# dtype: int64

# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

data = music_df

# %% [markdown]
# We need to give more weight to the latest releases in the recommendations. Let’s write a function to solve this problem

# %%
def calculate_weighted_popularity(release_date):
    # Convert the release date to datetime object
    release_date = datetime.strptime(release_date, '%Y-%m-%d')

    # Calculate the time span between release date and today's date
    time_span = datetime.now() - release_date

    # Calculate the weighted popularity score based on time span (e.g., more recent releases have higher weight)
    weight = 1 / (time_span.days + 1)
    return weight

# %%
# Normalize the music features using Min-Max scaling
scaler = MinMaxScaler()
music_features = music_df[['Danceability', 'Energy', 'Key', 
                           'Loudness', 'Mode', 'Speechiness', 'Acousticness',
                           'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].values
music_features_scaled = scaler.fit_transform(music_features)

# %%
# a function to get content-based recommendations based on music features
def content_based_recommendations(input_song_name, num_recommendations=5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get the index of the input song in the music DataFrame
    input_song_index = music_df[music_df['Track Name'] == input_song_name].index[0]

    # Calculate the similarity scores based on music features (cosine similarity)
    similarity_scores = cosine_similarity([music_features_scaled[input_song_index]], music_features_scaled)

    # Get the indices of the most similar songs
    similar_song_indices = similarity_scores.argsort()[0][::-1][1:num_recommendations + 1]

    # Get the names of the most similar songs based on content-based filtering
    content_based_recommendations = music_df.iloc[similar_song_indices][['Track Name', 'Artists', 'Album Name', 'Release Date', 'Popularity']]

    return content_based_recommendations

# %%
# a function to get hybrid recommendations based on weighted popularity
def hybrid_recommendations(input_song_name, num_recommendations=5, alpha=0.5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get content-based recommendations
    content_based_rec = content_based_recommendations(input_song_name, num_recommendations)

    # Get the popularity score of the input song
    popularity_score = music_df.loc[music_df['Track Name'] == input_song_name, 'Popularity'].values[0]

    # Calculate the weighted popularity score
    weighted_popularity_score = popularity_score * calculate_weighted_popularity(music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0])

    # Combine content-based and popularity-based recommendations based on weighted popularity
    hybrid_recommendations = content_based_rec
    hybrid_recommendations = hybrid_recommendations.append({
        'Track Name': input_song_name,
        'Artists': music_df.loc[music_df['Track Name'] == input_song_name, 'Artists'].values[0],
        'Album Name': music_df.loc[music_df['Track Name'] == input_song_name, 'Album Name'].values[0],
        'Release Date': music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0],
        'Popularity': weighted_popularity_score
    }, ignore_index=True)

    # Sort the hybrid recommendations based on weighted popularity score
    hybrid_recommendations = hybrid_recommendations.sort_values(by='Popularity', ascending=False)

    # Remove the input song from the recommendations
    hybrid_recommendations = hybrid_recommendations[hybrid_recommendations['Track Name'] != input_song_name]


    return hybrid_recommendations

# %%
input_song_name = "Top Lesi Poddi"
recommendations = hybrid_recommendations(input_song_name, num_recommendations=5)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Top Lesi Poddi':
#         Track Name                                            Artists  \
# 4          Deo Deo        Geetha Madhuri, Raghu Ram, Bheems Ceciroleo
# 2      Jai Balayya  Geetha Madhuri, Sahithi Chaganti, Satya Yamini...
# 3  Dillaku Dillaku                              Tippu, Geetha Madhuri
# 0   Dhimmathirigae                Simha, Geetha Madhuri, Priya Hemesh
# 1  Relaare Relaare                            Karthik, Geetha Madhuri
#
#                                           Album Name Release Date  Popularity
# 4  PSV Garudavega (Original Motion Picture Soundt...   2017-10-23        55.0
# 2                                            Akhanda   2021-12-09        51.0
# 3                                              Racha   2012-03-11        43.0
# 0                                        Srimanthudu   2015-07-18        40.0
# 1                                             Varudu   2010-03-08        33.0
# C:\Users\poorn\AppData\Local\Temp\ipykernel_5324\209674984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hybrid_recommendations = hybrid_recommendations.append({
